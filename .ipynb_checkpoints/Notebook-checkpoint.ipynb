# %%
import pandas as pd
import matplotlib.pyplot as plt
from collect import get_data
import numpy as np

# %%
get_data()
# Out:
# You are Successfully connected to -  ('PostgreSQL 9.6.16 on x86_64-pc-linux-gnu, compiled by gcc (GCC) 4.8.5 20150623 (Red Hat 4.8.5-39), 64-bit',)
#
# data updated
# ''

# %%
df_stock = pd.read_csv('Data/stock.csv')
df_price = pd.read_csv('Data/stock.csv')

# %%
df_stock.head()
# Out:
#                    created_at      serial              product        etat  \
# 0  2019-04-04 09:08:45.256129    10032417  WowSolar Controller        Neuf
# 1  2018-06-19 16:02:05.378547    70004907  WowSolar Controller   Endommagé
# 2  2021-02-14 19:19:18.298639   5328554C2             SKH Lamp   Endommagé
# 3  2018-09-08 13:52:06.976218    40004208  WowSolar Controller   Endommagé
# 4  2021-02-14 19:29:48.337128  80111106C2  WowSolar Lamp 140lm  Reposséder
#
#    prefix true_serial     stock_type     region  is_main_system  \
# 0     NaN    10032417       personal  TILLABERI            True
# 1     NaN    70004907  multi_manager     CENTRE           False
# 2     NaN   5328554C2  multi_manager      THIES           False
# 3     NaN    40004208  multi_manager     BAMAKO           False
# 4     NaN  80111106C2       personal      MATAM           False
#
#    main_system_id  first_main_system_id  \
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN               22776.0
# 3             NaN                   NaN
# 4             NaN               67898.0
#
#                               stock_name     systems         product_type  \
# 0          halidou abdou - halidou.abdou  WowSolar60           WowSolar60
# 1                            OUAGADOUGOU         NaN  WowSolar Controller
# 2                                  Thies         NaN             SKH Lamp
# 3                                 BAMAKO         NaN  WowSolar Controller
# 4  SEYDOU ABDOULAYE DIALLO - MATAMPOLY33         NaN  WowSolar Lamp 140lm
#
#    country  is_archived serial_number  cost_price       carton_id   valeur
# 0    Niger        False      10032417     34089.0  CTN#A000003218  34089.0
# 1  Burkina        False      70004907     26558.0  CTN#A000000861  26558.0
# 2  Senegal        False           NaN         NaN             NaN      NaN
# 3     Mali        False      40004208     30684.0  CTN#A000000702  30684.0
# 4  Senegal        False           NaN         NaN             NaN      NaN

# %%
print(f'le shape du dataframe {df_stock.shape}')
df_stock.isnull().sum()
# Out:
# le shape du dataframe (79102, 20)
# created_at                  0
# serial                      0
# product                     0
# etat                        0
# prefix                  74369
# true_serial                 0
# stock_type                  0
# region                      0
# is_main_system              0
# main_system_id          79090
# first_main_system_id    48453
# stock_name                  0
# systems                 73941
# product_type                0
# country                     0
# is_archived                 0
# serial_number           56876
# cost_price              59489
# carton_id               61964
# valeur                  57125
# dtype: int64

# %%
df_stock = df_stock[~df_stock['true_serial'].isnull()]
df_stock.shape
# Out:
# (79102, 20)

# %%
print(f'Nombre de serial en stock {df_stock.true_serial.nunique()}')
print(f'Verification de doublons {df_stock.true_serial.nunique()== df_stock.shape[0]}')
# Out:
# Nombre de serial en stock 79013
# Verification de doublons False

# %%
df_stock['true_serial'].duplicated().sum()
# Out:
# 89

# %%
df_stock[df_stock['true_serial'].duplicated()]
# Out:
#                        created_at      serial                   product  \
# 4116   2021-02-14 20:38:34.470105      0908C2                Panel Fan
# 4117   2021-02-14 20:38:34.470105      0908C2                Panel Fan
# 4118   2021-02-14 20:38:34.470105      0908C2                Panel Fan
# 4119   2021-02-14 20:38:34.470105      0908C2                Panel Fan
# 7336   2021-02-14 19:18:02.316344  30129561C3       WowSolar Lamp 140lm
# ...                           ...         ...                       ...
# 73941  2021-02-14 19:14:37.020277  50103540C2       WowSolar Lamp 140lm
# 75330  2021-02-14 19:18:02.332340  30129561C4       WowSolar Lamp 140lm
# 75964  2021-02-19 22:32:04.843582   895000016  WowSolar Batterie GM 80W
# 77864  2021-02-14 19:18:02.346726  30129561C5       WowSolar Lamp 140lm
# 78606  2021-02-17 19:04:54.242262  30008808C4       WowSolar Lamp 140lm
#
#              etat  prefix true_serial     stock_type  region  is_main_system  \
# 4116   Reposséder     NaN      0908C2  multi_manager  RIVERS           False
# 4117   Reposséder     NaN      0908C2  multi_manager  RIVERS           False
# 4118   Reposséder     NaN      0908C2  multi_manager  RIVERS           False
# 4119   Reposséder     NaN      0908C2  multi_manager  RIVERS           False
# 7336         Neuf     NaN  30129561C3  multi_manager  BAMAKO           False
# ...           ...     ...         ...            ...     ...             ...
# 73941        Neuf     NaN  50103540C2       personal   KAYES           False
# 75330        Neuf     NaN  30129561C4  multi_manager  BAMAKO           False
# 75964     recycle   895.0      000016  multi_manager   DAKAR           False
# 77864        Neuf     NaN  30129561C5  multi_manager  BAMAKO           False
# 78606     recycle     NaN  30008808C4       personal   SEGOU           False
#
#        main_system_id  first_main_system_id                  stock_name  \
# 4116              NaN               53690.0        ZZZ - Abimbola Omeni
# 4117              NaN               53690.0        ZZZ - Abimbola Omeni
# 4118              NaN               53690.0        ZZZ - Abimbola Omeni
# 4119              NaN               53690.0        ZZZ - Abimbola Omeni
# 7336              NaN               63245.0                      BAMAKO
# ...               ...                   ...                         ...
# 73941             NaN               62050.0   Kaly Diallo - kaly.diallo
# 75330             NaN               63245.0                      BAMAKO
# 75964             NaN               46436.0      Stock TEST à supprimer
# 77864             NaN               63245.0                      BAMAKO
# 78606             NaN                1207.0  Dramane Traoré - dogofri01
#
#       systems              product_type  country  is_archived serial_number  \
# 4116      NaN                Panel Fan   Nigeria         True           NaN
# 4117      NaN                Panel Fan   Nigeria         True           NaN
# 4118      NaN                Panel Fan   Nigeria         True           NaN
# 4119      NaN                Panel Fan   Nigeria         True           NaN
# 7336      NaN       WowSolar Lamp 140lm     Mali        False           NaN
# ...       ...                       ...      ...          ...           ...
# 73941     NaN       WowSolar Lamp 140lm     Mali        False           NaN
# 75330     NaN       WowSolar Lamp 140lm     Mali        False           NaN
# 75964     NaN  WowSolar Batterie GM 80W  Senegal        False           NaN
# 77864     NaN       WowSolar Lamp 140lm     Mali        False           NaN
# 78606     NaN       WowSolar Lamp 140lm     Mali        False           NaN
#
#        cost_price carton_id  valeur
# 4116          NaN       NaN     0.0
# 4117          NaN       NaN     0.0
# 4118          NaN       NaN     0.0
# 4119          NaN       NaN     0.0
# 7336          NaN       NaN     NaN
# ...           ...       ...     ...
# 73941         NaN       NaN     NaN
# 75330         NaN       NaN     NaN
# 75964         NaN       NaN     NaN
# 77864         NaN       NaN     NaN
# 78606         NaN       NaN     NaN
#
# [89 rows x 20 columns]

# %%
df_stock[df_stock['is_archived']==True]['stock_name'].unique()
# Out:
# array(['ZZZ - LGS', 'ZZZ', 'ZZZ - Michael Sonubi',
#        'YYY - Kits en cours de remboursement', 'XXX - Sold Component',
#        'ZZZ - Sunday Osajiokwu', 'ZZZ - Abimbola Omeni',
#        'YYY - Ongoing Reimbursement', 'XXX',
#        'ZZZ - Batteries fin de contrat', 'ZZZ - Monday Oliseyenum',
#        'ZZZ - SN', 'XXX- Erreurs de déploiement', 'ZZZ - Paschal Ihekuna',
#        'ZZZ - Lenny Okoh', 'YYY - Reimbursed Kits', 'ZZZ - Titus Gesa',
#        'YYY - Kits perdus remboursés', 'ZZZ - Chinomso Ejiogu', 'XXX ML'],
#       dtype=object)

# %% [markdown]
# ## Systems

# %%
df_system = df_stock[df_stock['is_main_system']==True]
print(f'Nombre de systems compléte {df_system.shape}')
df_system.head()
# Out:
# Nombre de systems compléte (5161, 20)
#                     created_at          serial                   product  \
# 0   2019-04-04 09:08:45.256129        10032417       WowSolar Controller
# 11  2022-03-14 19:01:47.039286   4544521430153         Oolu TV Screen 43
# 15  2021-09-21 16:38:26.697096      4521320277         Oolu TV Screen 32
# 21  2020-01-22 15:17:39.543211  L1901909000789  Portable light component
# 22  2022-01-20 12:08:10.215389      4521320857         Oolu TV Screen 32
#
#     etat  prefix     true_serial     stock_type           region  \
# 0   Neuf     NaN        10032417       personal        TILLABERI
# 11  Neuf   454.0      4521430153  multi_manager           BAMAKO
# 15  Neuf     NaN      4521320277  multi_manager       ZIGUINCHOR
# 21  Neuf     NaN  L1901909000789  multi_manager  Lagos Warehouse
# 22  Neuf     NaN      4521320857  multi_manager  Lagos Warehouse
#
#     is_main_system  main_system_id  first_main_system_id  \
# 0             True             NaN                   NaN
# 11            True             NaN                   NaN
# 15            True             NaN                   NaN
# 21            True             NaN                   NaN
# 22            True             NaN                   NaN
#
#                        stock_name                              systems  \
# 0   halidou abdou - halidou.abdou                           WowSolar60
# 11                         BAMAKO                       Oolu SolarTV43
# 15                     Ziguinchor                       Oolu SolarTV32
# 21                LAGOS WAREHOUSE  L190 Portable light + phone charger
# 22                LAGOS WAREHOUSE                    Oolu SolarTV32 NG
#
#                            product_type  country  is_archived   serial_number  \
# 0                            WowSolar60    Niger        False        10032417
# 11                       Oolu SolarTV43     Mali        False      4521430153
# 15                       Oolu SolarTV32  Senegal        False      4521320277
# 21  L190 Portable light + phone charger  Nigeria        False  L1901909000789
# 22                    Oolu SolarTV32 NG  Nigeria        False      4521320857
#
#     cost_price        carton_id     valeur
# 0     34089.00   CTN#A000003218   34089.00
# 11   256311.00              NaN  256311.00
# 15   208690.00              NaN  208690.00
# 21     6844.78  CTN#OMNIVOLTAIC    6844.78
# 22         NaN              NaN        NaN

# %%
df_system.isnull().sum()
# Out:
# created_at                 0
# serial                     0
# product                    0
# etat                       0
# prefix                  3424
# true_serial                0
# stock_type                 0
# region                     0
# is_main_system             0
# main_system_id          5161
# first_main_system_id    5161
# stock_name                 0
# systems                    0
# product_type               0
# country                    0
# is_archived                0
# serial_number             23
# cost_price              1553
# carton_id               2590
# valeur                  1444
# dtype: int64

# %%
value_condition = (df_system['etat'].isin(['Endommagé','waste','canceled']) | df_system['is_archived']==True)
loss_condition = (df_system['etat'].isin(['Endommagé','waste','canceled']) | lower(df_system['stock_name']).startwith('zzz'))

df_system['valeur'] = np.where(value_condition,0,df_system['cost_price'])
df_system['loss'] = np.where(loss_condition,0,df_system['cost_price'])

df_system.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20328/3804152024.py in <module>
#       1 value_condition = (df_system['etat'].isin(['Endommagé','waste','canceled']) | df_system['is_archived']==True)
# ----> 2 loss_condition = (df_system['etat'].isin(['Endommagé','waste','canceled']) | lower(df_system['stock_name']).startwith('zzz'))
#       3
#       4 df_system['valeur'] = np.where(value_condition,0,df_system['cost_price'])
#       5 df_system['loss'] = np.where(loss_condition,0,df_system['cost_price'])
#
# NameError: name 'lower' is not defined

# %%
df_system[df_system['is_archived']==True]
# Out:
#                        created_at          serial                   product  \
# 94     2019-01-29 09:56:47.503959        20022120       WowSolar Controller
# 105    2019-01-25 11:10:36.169410        10020114       WowSolar Controller
# 194    2020-03-10 11:13:53.706420       497321250             Fan component
# 242    2020-05-27 11:59:43.618913       497322187             Fan component
# 582    2019-02-28 14:43:19.952707        00029475       WowSolar Controller
# ...                           ...             ...                       ...
# 78102  2019-12-10 08:30:29.127104        20022984       WowSolar Controller
# 78160  2020-01-22 11:29:16.845000  L1901909000675  Portable light component
# 78161  2020-01-22 11:29:16.719830  L1901909000672  Portable light component
# 78164  2019-02-04 14:44:54.791207        50021361       WowSolar Controller
# 78197  2020-01-22 17:06:21.523002  L1901909000724  Portable light component
#
#        etat  prefix     true_serial     stock_type  region  is_main_system  \
# 94     Neuf     NaN        20022120  multi_manager   LAGOS            True
# 105    Neuf     NaN        10020114  multi_manager   LAGOS            True
# 194    Neuf   497.0          321250  multi_manager   LAGOS            True
# 242    Neuf   497.0          322187  multi_manager   LAGOS            True
# 582    Neuf     NaN        00029475  multi_manager  CENTRE            True
# ...     ...     ...             ...            ...     ...             ...
# 78102  Neuf     NaN        20022984  multi_manager   LAGOS            True
# 78160  Neuf     NaN  L1901909000675  multi_manager   LAGOS            True
# 78161  Neuf     NaN  L1901909000672  multi_manager   LAGOS            True
# 78164  Neuf     NaN        50021361  multi_manager   LAGOS            True
# 78197  Neuf     NaN  L1901909000724  multi_manager   LAGOS            True
#
#        main_system_id  first_main_system_id                   stock_name  \
# 94                NaN                   NaN                    ZZZ - LGS
# 105               NaN                   NaN                    ZZZ - LGS
# 194               NaN                   NaN                    ZZZ - LGS
# 242               NaN                   NaN       ZZZ - Sunday Osajiokwu
# 582               NaN                   NaN                          ZZZ
# ...               ...                   ...                          ...
# 78102             NaN                   NaN                    ZZZ - LGS
# 78160             NaN                   NaN  YYY - Ongoing Reimbursement
# 78161             NaN                   NaN  YYY - Ongoing Reimbursement
# 78164             NaN                   NaN       ZZZ - Sunday Osajiokwu
# 78197             NaN                   NaN  YYY - Ongoing Reimbursement
#
#                                    systems  \
# 94                          WowSolar100 NG
# 105                         WowSolar100 NG
# 194            Oolu Solar Fan V1 + adapter
# 242            Oolu Solar Fan V1 + adapter
# 582                             WowSolar60
# ...                                    ...
# 78102                       WowSolar100 NG
# 78160  L190 Portable light + phone charger
# 78161  L190 Portable light + phone charger
# 78164                       WowSolar100 NG
# 78197  L190 Portable light + phone charger
#
#                               product_type  country  is_archived  \
# 94                          WowSolar100 NG  Nigeria         True
# 105                         WowSolar100 NG  Nigeria         True
# 194            Oolu Solar Fan V1 + adapter  Nigeria         True
# 242            Oolu Solar Fan V1 + adapter  Nigeria         True
# 582                             WowSolar60  Burkina         True
# ...                                    ...      ...          ...
# 78102                       WowSolar100 NG  Nigeria         True
# 78160  L190 Portable light + phone charger  Nigeria         True
# 78161  L190 Portable light + phone charger  Nigeria         True
# 78164                       WowSolar100 NG  Nigeria         True
# 78197  L190 Portable light + phone charger  Nigeria         True
#
#         serial_number  cost_price        carton_id  valeur
# 94           20022120    24472.68              NaN     0.0
# 105          10020114    24472.68              NaN     0.0
# 194            321250    19967.00  CTN#FAN28012020     0.0
# 242            322187         NaN  CTN#FAN27052020     0.0
# 582          00029475    29846.00   CTN#A000003660     0.0
# ...               ...         ...              ...     ...
# 78102        20022984    24472.68        CTN#AMPED     0.0
# 78160  L1901909000675     6844.78  CTN#OMNIVOLTAIC     0.0
# 78161  L1901909000672     6844.78  CTN#OMNIVOLTAIC     0.0
# 78164        50021361    24472.68              NaN     0.0
# 78197  L1901909000724     6844.78  CTN#OMNIVOLTAIC     0.0
#
# [552 rows x 20 columns]
